# %% [markdown]
# **QUELQUES EXERCICES POUR PRATIQUER LES LISTES ET BOUCLES**

# %% [markdown]
# ***Exo 1. Exercices avec boucle for (Boucles Bornées)***
#
# Parcours simple : Créer une liste de fruits et afficher chaque fruit avec la phrase "J'aime manger : [fruit]"

# %%
# Saisissez votre réponse ici

# %% [markdown]
# ***Exo 2: Somme d'éléments ***
#
# Soit la liste nombres = [10, 20, 30, 40]. Calculer la somme de tous les éléments sans utiliser la fonction sum().

# %%
# Saisissez votre réponse ici

# %% [markdown]
# ***Exo 3: Filtrage***
#
# À partir d'une liste de nombres [2, 5, 8, 11, 14], créer une nouvelle liste contenant uniquement les nombres pairs.

# %%
# Saisissez votre réponse ici

# %% [markdown]
# ***Exo 4: Modification***
#
# Augmenter de 10% tous les prix contenus dans une liste prix = [100, 50, 20].

# %%
# Saisissez votre réponse ici

# %% [markdown]
# ***Exo 5: Compteur***
#
# Afficher les nombres pairs de 0 à 20 inclus.

# %%
# Saisissez votre réponse ici

# %% [markdown]
# ***Exo 6: Validation***
#
# Demander à l'utilisateur de saisir un mot de passe et répéter la demande tant que le mot de passe n'est pas "python123".

# %%
# Saisissez votre réponse ici

# %% [markdown]
# ***Exo 7: Parcours de liste***
#
# Parcourir une liste de prénoms ["Alice", "Bob", "Charlie"] avec un index et afficher "Bonjour [prénom]" jusqu'à la fin de la liste

# %%
# Saisissez votre réponse ici
